# %%
dataset1= "/content/drive/MyDrive/ML LAB DATASETs/Iris.csv"
dataset2= "/content/drive/MyDrive/ML LAB DATASETs/KNNAlgorithmDataset.csv"
dataset3= "/content/drive/MyDrive/ML LAB DATASETs/Naive-Bayes-Classification-Data.csv"

# %%
import pandas as pd
print("Datset1")
# Load the dataset (Replace 'your_dataset.csv' with your actual file)
df = pd.read_csv(dataset1)
print(df.head())

print("Datset2")
# Load the dataset (Replace 'your_dataset.csv' with your actual file)
df = pd.read_csv(dataset2)
print(df.head())

print("Datset3")
# Load the dataset (Replace 'your_dataset.csv' with your actual file)
df = pd.read_csv(dataset3)
print(df.head())
# Out:
# Datset1
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# Datset2
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

def evaluate_model(X, y, dataset_name):
    """
    Trains Naïve Bayes and evaluates it on different train-test splits
    """
    for split in [0.3, 0.2, 0.1]:  # Corresponds to 70-30, 80-20, 90-10 splits
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split, random_state=42)

        # Train model
        model = GaussianNB()
        model.fit(X_train, y_train)

        # Predictions
        y_pred = model.predict(X_test)

        # Evaluation
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average="weighted")
        recall = recall_score(y_test, y_pred, average="weighted")
        f1 = f1_score(y_test, y_pred, average="weighted")
        conf_matrix = confusion_matrix(y_test, y_pred)

        # Print Results
        print(f"\n📌 **{dataset_name} Dataset ({100-int(split*100)}-{int(split*100)}) Split Results**")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        print("Confusion Matrix:\n", conf_matrix)

        # Plot Confusion Matrix
        plt.figure(figsize=(5,4))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix - {dataset_name} ({100-int(split*100)}-{int(split*100)})")
        plt.show()

# %%
df1 = pd.read_csv("/content/drive/MyDrive/ML LAB DATASETs/Iris.csv")  # Replace with actual file path
df1.drop(columns=['Id'], inplace=True)  # Remove unnecessary column

# Split features & target
X1 = df1.drop(columns=['Species'])
y1 = df1['Species']

# Evaluate on different splits
evaluate_model(X1, y1, "Iris")
# Out:
# 📌 **Iris Dataset (70-30) Split Results**
# Accuracy: 0.9778
# Precision: 0.9794
# Recall: 0.9778
# F1 Score: 0.9777
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 12  1]
#  [ 0  0 13]]
# 📌 **Iris Dataset (80-20) Split Results**
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# 📌 **Iris Dataset (90-10) Split Results**
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# Confusion Matrix:
#  [[6 0 0]
#  [0 6 0]
#  [0 0 3]]

# %%
df2 = pd.read_csv("/content/drive/MyDrive/ML LAB DATASETs/KNNAlgorithmDataset.csv")  # Replace with actual file path
df2.drop(columns=['id', 'Unnamed: 32'], inplace=True)  # Remove unnecessary columns

# Encode Target Variable (M → 1, B → 0)
X2 = df2.drop(columns=['diagnosis'])
y2 = df2['diagnosis'].map({'M': 1, 'B': 0})

# Evaluate on different splits
evaluate_model(X2, y2, "Breast Cancer")
# Out:
# 📌 **Breast Cancer Dataset (70-30) Split Results**
# Accuracy: 0.9415
# Precision: 0.9414
# Recall: 0.9415
# F1 Score: 0.9413
# Confusion Matrix:
#  [[104   4]
#  [  6  57]]
# 📌 **Breast Cancer Dataset (80-20) Split Results**
# Accuracy: 0.9737
# Precision: 0.9748
# Recall: 0.9737
# F1 Score: 0.9735
# Confusion Matrix:
#  [[71  0]
#  [ 3 40]]
# 📌 **Breast Cancer Dataset (90-10) Split Results**
# Accuracy: 0.9825
# Precision: 0.9829
# Recall: 0.9825
# F1 Score: 0.9823
# Confusion Matrix:
#  [[40  0]
#  [ 1 16]]

# %%
df3 = pd.read_csv("/content/drive/MyDrive/ML LAB DATASETs/Naive-Bayes-Classification-Data.csv")  # Replace with actual file path

# Split features & target
X3 = df3.drop(columns=['diabetes'])
y3 = df3['diabetes']

# Evaluate on different splits
evaluate_model(X3, y3, "Diabetes")
# Out:
# 📌 **Diabetes Dataset (70-30) Split Results**
# Accuracy: 0.9331
# Precision: 0.9331
# Recall: 0.9331
# F1 Score: 0.9331
# Confusion Matrix:
#  [[130  10]
#  [ 10 149]]
# 📌 **Diabetes Dataset (80-20) Split Results**
# Accuracy: 0.9296
# Precision: 0.9296
# Recall: 0.9296
# F1 Score: 0.9296
# Confusion Matrix:
#  [[86  7]
#  [ 7 99]]
# 📌 **Diabetes Dataset (90-10) Split Results**
# Accuracy: 0.9100
# Precision: 0.9117
# Recall: 0.9100
# F1 Score: 0.9100
# Confusion Matrix:
#  [[45  3]
#  [ 6 46]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data from the experiment
datasets = ["Iris (70-30)", "Iris (80-20)", "Iris (90-10)",
            "Breast Cancer (70-30)", "Breast Cancer (80-20)", "Breast Cancer (90-10)",
            "Diabetes (70-30)", "Diabetes (80-20)", "Diabetes (90-10)"]

accuracy = [0.9778, 1.0000, 1.0000, 0.9415, 0.9737, 0.9825, 0.9331, 0.9296, 0.9100]
precision = [0.9794, 1.0000, 1.0000, 0.9414, 0.9748, 0.9829, 0.9331, 0.9296, 0.9117]
recall = [0.9778, 1.0000, 1.0000, 0.9415, 0.9737, 0.9825, 0.9331, 0.9296, 0.9100]
f1_score = [0.9777, 1.0000, 1.0000, 0.9413, 0.9735, 0.9823, 0.9331, 0.9296, 0.9100]

# Convert values to percentage for better visualization
accuracy = [x * 100 for x in accuracy]
precision = [x * 100 for x in precision]
recall = [x * 100 for x in recall]
f1_score = [x * 100 for x in f1_score]

# Set figure size
plt.figure(figsize=(12, 6))

# Define bar width and positions
bar_width = 0.2
x = np.arange(len(datasets))

# Create grouped bar chart
plt.bar(x - 1.5*bar_width, accuracy, width=bar_width, label="Accuracy", color="blue")
plt.bar(x - 0.5*bar_width, precision, width=bar_width, label="Precision", color="green")
plt.bar(x + 0.5*bar_width, recall, width=bar_width, label="Recall", color="red")
plt.bar(x + 1.5*bar_width, f1_score, width=bar_width, label="F1 Score", color="purple")

# Labels and title
plt.xlabel("Dataset and Split", fontsize=12)
plt.ylabel("Score (%)", fontsize=12)
plt.title("Naïve Bayes Performance Across Different Datasets and Splits", fontsize=14)
plt.xticks(ticks=x, labels=datasets, rotation=45, ha="right")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)
# Adjust y-axis to show only values above 90%
plt.ylim(90, 101)

# Show plot
plt.tight_layout()
plt.show()
